# %%
text = "<k-digital training 3기>"
text1 = 'abc'
print(text[0])
print(text[-1])
print(text.capitalize())
print(text.title())
print(text1.title())
print(text1.upper())
print(text1.capitalize())

# %% [markdown]
# ## 과제, <K-digital training 3기>

# %%
text1 = "   <k-digital training 3기>   "
text2 = ';'
# <k-digital training 3기>;로 출력해보기
# <k-digital training 3기>    ;로 출력해보기
#    <k-digital training 3기>;로 출력해보기
print(text1.strip() + text2)
print(text1.lstrip() + text2)
print(text1.rstrip() + text2)

# %%
# <div>k-digital training 3기</title>
# <div>k-digital training 3기</div>

text = "<title>k-digital training 3기</title>"

text.replace('<title>', '<div>')
text.replace('title', 'div')

# %%
import re
text = ('111<head>안녕하세요</head>22')

a = re.search('<head>.+</head>', text)
print(a.group())

# %%
import requests
URL='https://naver.com'
response = requests.get(URL)
print(response.text)

# %%
text = '''<meta name="description"
content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>'''

import re
body = re.search('([가-힣]+ *)+',text)
# body = re.search('([가-힣]+\s?)+',text)
print(body.group())

# %%
text = ('111<head>안녕하세요</head>22')

import re
body = re.search('[가-힣]+', text)
print(body.group())

# %%
# 'k-digital training 3기'를 출력하세요
import re
text ='<title>k-digital training 3기</title>'

# text = re.sub("<title>","",text)
# text = re.sub("/<title>", "", text)

text = re.sub('<.+?>','',text)
print(text)

# %%
# 'k-digital training 3기'를 출력하세요
text = '''<head>안녕하세요...<title>k-digital training 3기</title>
반갑습니다...</head>'''

import re

a = re.sub('<.+?>','',text)
b = re.sub('([가-힣]+...)','',a)

print(b)

# %%
text = '''<head> 안녕하세요...<title>k-digital training 3기</title>
반갑습니다...</head>'''
body = re.search('[a-z]-.+[가-힣]',text)
print(body.group())

# %%
text = '''<head> 안녕하세요... <title>k-digital training 3기</title>
반갑습니다...</head>'''
text = re.sub('.+<title>','', text)
# p = re.compile('</title>.+', re.DOTALL)
# text = re.sub(p,'', text)
print(text)

# %% [markdown]
# #### requests 모듈 : pip install requests 명령어로 설치, anaconda를 설치하면 기본적으로 설치돼 있음.
# - import requests로 모듈 호출 후 사용

# %%
import requests
URL = 'https://www.naver.com'
response = requests.get(URL)
print(response.status_code)  #status_code는 그냥 코드 상태 알려주는 것
#이렇게 하면 제대로 된 거면 2로 시작함. 서버가 잘못되면 5로 시작, 찾을 수 없음404
print(response.text)

# %%
html_data = response.text
# print(html_data)
print(html_data.find('네이버'))
print(html_data[365:368])

# %%
# Q. '네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나보세요'를 출력하세요.
print(html_data.find('네이버 메인에서'))
print(html_data[365:397])

# %%
# Q. 위 문제를 정규 표현식으로 출력하세요.
import re
a = re.search('([가-힣]+ *)+',html_data)
print(a.group())

# %%
content = html_data.split('<meta property=')[1]
content = re.search('네이버', content)
print(content.group())

# %%
# get 메소드에 params 인자를 넣어 함께 get 요청(파라미터 : query)
import requests 
URL = 'https://search.naver.com/search.naver'
par = {'query':'aa'} #네이버에 aa를 검색했을 때 query값에 aa가 추가된다는 뜻 그걸 검색하지 않고 넣은것
response = requests.get(URL,params=par)  #parse로 나눴을 때 params에 해당하는게 여기에 들어간다는뜻
print(response.status_code)
print(response.text)

# %%
# get 메소드에 params 인자를 넣어 함께 get 요청(파라미터 : query)
import requests 
URL = 'https://www.naver.com'
response = requests.get(URL)
text = response.text
body = re.search('<h3.*/h3>',content)
body.group()

# %%
import requests
URL = 'https://www.naver.com'
response = requests.get(URL)
content = response.text
body = re.search('<h3.*/h3>',content)
body.group()
text = re.search('[가-힣]+',body.group())
# body = re.sub('<.+?>', '', body)
print(text.group())

# %%
# 해당 싸이트에서 원피스 출력하기
import requests
URL = 'https://datalab.naver.com'
response = requests.get(URL)
content = response.text

temp = content.split('<span class="title">')[1]
print(temp)
print('--------------------------------------')
print(temp.split('</span>')[0])

# %%
import requests
URL = 'https://datalab.naver.com'
response = requests.get(URL)
content = response.text
a = re.search('<span class="title">원피스</span>', content)
a.group()
text = re.search('[가-힣]+',a.group())
print(text.group())

# %%
# 'https://search.shopping.naver.com/best100v2/main.nhn'에서 크록스를 출력하세요
import requests
URL = 'https://search.shopping.naver.com/best100v2/main.nhn'
response = requests.get(URL)
content = response.text
print(content.find('크록스'))
print(content[19398:19401])

# %%
# Q. URL = 'http://naver.com'에서 split()함수와 정규표현식을 이용하여 
# ['메일','카페','블로그','지식iN','쇼핑']을 출력하세요

import re
import requests
URL = 'http://naver.com'
response = requests.get(URL)
html_data = response.text
li = []
for i in range(5):
    result = html_data.split('<li class="nav_item">')[i+1]
    word = re.sub('<.*?>','',result)
    word = re.sub(r'\n','',word)
    li.append(word)
print(li)
# Out:
# ['메일', '카페', '블로그', '지식iN', '쇼핑']

# %%
import urllib
URL = 'https://www.naver.com'
request = urllib.request.Request(URL)
print(request)
print(request.full_url)
print(request.type)
print(request.host)
# Out:
# ...
# https://www.naver.com
# https
# www.naver.com

# %%
import urllib
URL = 'https://www.naver.com'
response = urllib.request.urlopen(URL)
byte_data = response.read(500) #앞에서부터 500개만 보여줌
print(byte_data)
# text_data = byte_data.decode('utf-8')
# print(text_data)
# Out:
# b'\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <m'

# %%
import urllib
URL = 'https://www.naver.com'
response = urllib.request.urlopen(URL)
byte_data = response.read(500) #앞에서부터 500개만 보여줌
text_data = byte_data.decode('utf-8')
print(text_data)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <m

# %%
# 웹 이미지 같은걸 가져와서 저장
# urllib.request.urlretrieve():웹상의 이미지 저장
import urllib.request
img_src = 'https://homepages.cae.wisc.edu/~ece533/images/tulips.png'
new_name = 'img.png'
urllib.request.urlretrieve(img_src, new_name)
# Out:
# ('img.png', <http.client.HTTPMessage at 0x1be8a08c0a0>)

# %%
# 단순한 패턴을 읽을 때는 복잡한 정규표현식 보다는 간단한 parse 모듈을 사용
# urllib.parse : url을 6개로 분리하여 반환
import urllib
parse = urllib.parse.urlparse('https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai')
print(parse) #출력하면 6개로 나뉜걸 확인할 수 있다. 
print(parse[0])
print(parse[5]) #fragment가 비어있어서 아무것도 안나옴
print(parse[:5])
print(parse.query)

# %%
# 튜플(변경 불가능)로 반환하기 때문네 바뀌지 않고 에러나는 것. 그럼 리스트로 변경해야함
import urllib
parse = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse)
parse = list(parse)#리스트로 변경
parse[1] = 'blog.daum.net' #리스트화 하지 않으면 바꿔지지 않고 에러가 남
print(parse)

# %%
# 1-1. 원하는 웹사이트를 requests모듈과 urllib모듈로 가져와서 text로 출력하세요.: requests
import requests
URL = 'https://comic.naver.com/webtoon/weekday.nhn' #네이버 웹툰 싸이트
response = requests.get(URL)
content = response.text
print(content)

# %%
# 1-2. 원하는 웹사이트를 requests모듈과 urllib모듈로 가져와서 text로 출력하세요. -urllib
import urllib
URL = 'https://comic.naver.com/webtoon/weekday.nhn' #네이버 웹툰 싸이트
response = urllib.request.urlopen(URL)
content = response.read()
text_content = content.decode('utf-8')
print(text_content)

# %%
# 2. 위의 텍스트에서 특정 단어를 출력하세요.
import requests
import re
URL = 'https://comic.naver.com/webtoon/weekday.nhn'
response = requests.get(URL)
content = response.text
li = []
for i in range(4):
    result = content.split('<span class="Ntxt_')[i+1]
    word = re.findall('[가-힣]+',result)
    li.append(word)
print(li)
# Out:
# [['웹툰', '홈'], ['웹툰'], ['베스트', '도전'], ['도전만화']]

# %%
# 3. 웹에서 이미지를 다운 받아 저장하세요.(가능한 이미지 선택)
import urllib
URL = 'https://t1.daumcdn.net/cfile/blog/996120355B38DDB128'
rename = 'img2.png'
urllib.request.urlretrieve(URL, rename)
# Out:
# ('img2.png', <http.client.HTTPMessage at 0x1be8b3d11c0>)

# %%
# 4. 도전과제 : 네이버 영화 랭킹 가져와서 첫번째 영화제목을 출력하세요.
import requests
URL = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn'

# %%
# 5. 도전과제 : 네이버 영화 랭킹 가져와서 전체 영화제목 출력하세요.

# %%
# 과제
# <K-digital training 3기>
text = "k-digital training 3기"

a = text.capitalize()
print('<'+a+'>')
# Out:
# <K-digital training 3기>

# %%
# 홈페이지를 로컬에 파일로 저장
import urllib
request = urllib.request.Request('https://www.naver.com')
data = urllib.request.urlopen(request).read()
f = open('pc.html', 'wb')
f.write(data)
f.close()

# %%
with open('pc.html', 'rb') as f:
    data =f.read().decode('utf-8')
    print(data)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...
