# %% [markdown]
# ## 간략한 개요
#
# 개발 목적 : 매일 조금씩이라도 운동을 하게 하기 위한
# 개발 환경  : 파이썬
# 적용 개념 : 클래스
# 시나리오
# 클래스 관계도
# 후기
#
#
# 개요 :
# 선택하는 사람의 나이 등
# 오늘은 어떤 운동을 할까? - 스트레칭에서부터 간단한 홈트까지
# 1. 운동 목적
# 2. 오늘 몸 상태
# 3. 여유 시간
# 4. 운동추천
# 5. 예시 이미지 로딩

# %% [markdown]
# ## 필요한 클래스 함수 만들기

# %%
class AllAboutWorkout:
    def __init__(self):
        name = input('반갑습니다 사용자님, 성함을 입력해주세요 : ')
        print("{}님께서 집에서도 할 수 있는, 오늘의 운동을 추천해드립니다.".format(name))
        
    def body_condition(self): #몸상태
        while 1 :
            cq = int(input('오늘의 몸 상태는 어떠세요?\n 1. 활력 넘침 2. 보통 3. 피곤함: '))
            c_li = ['활력넘침', '보통', '피곤함']
            if cq < 4:
                print('{}번 {}을 선택하셨습니다. {}님의 컨디션에 맞는 운동을 추천하기 위해 정보를 수집중입니다.'.format(cq, c_li[cq-1], name))
                break
            else : 
                print('목록에 있는 번호로 다시 입력해주세요.')
                continue
                
    def available_time(self): #운동가능시간
        while 1:
            tq = int(input('운동 가능한 시간을 알려주세요.\n 1. 10분이하 2. 30분이하 3. 1시간 이하 : '))
            t_li = ['10분이하', '30분이하', '1시간이하']
            if tq < 4 :
                print('{}번 {}를(을) 선택하셨습니다. {}님의 편의에 맞는 운동을 추천드리기 위해 더 똑똑해지고 있습니다.'.format(tq, t_li[tq-1],name))
                break      
            else :
                print('목록에 있는 번호로 다시 입력해주세요.')
                continue 
                      
    def program_function(self): #프로그램 사용목적
        while 1 :
            pq = int(input('프로그램의 사용 목적을 알려주세요.\n 1.운동 종류 둘러보기 2.사용자 맞춤 운동 추천받기 : '))
            p_li = ['운동 종류 둘러보기', '사용자 맞춤 운동 추천받기']
            if pq <3 :
                print('{}번 {}를 선택하셨습니다. {}님이 원하시는 프로그램을 제공해드리겠습니다. 잠시만 기다려주세요.'.format(pq, p_li[pq-1],name))
                break
            else :
                print('목록에 있는 번호로 다시 입력해주세요')
                continue
              
    def workoutrec(self): #운동목적
        while 1:
            wq = int(input('운동 목적을 입력해주세요.\n 1.스트레칭 2.근력증진 3.체중감량 : '))
            w_li = ['스트레칭', '근력증진', '체중감량']
            if wq < 4:
                print('{}번 {}를 선택하셨습니다. {}님이 원하시는 프로그램을 제공해드리겠습니다. 잠시만 기다려주세요.'.format(wq, w_li[wq-1], name))
                break
            else :
                print('목록에 있는 번호로 다시 입력해주세요.')
                continue 

workoutlist = ['스트레칭','자기 전 요가', '5분 복근만들기', '30분 유산소 운동', '1분 플랭크', '하체운동', '어깨운동','이두/삼두운동','생활속운동','거북목방지운동','걷기/계단오르내리기']

# %% [markdown]
# ## 뼈대만들기

# %%
            
from time import sleep
def start1():
    name = input('반갑습니다 사용자님, 성함을 입력해주세요 : ')
    print("{}님께서 집에서도 할 수 있는, 오늘의 운동을 추천해드립니다.".format(name))
    
def program_function(): #프로그램 사용목적
#     while 1 :
#         pq = int(input('프로그램의 사용 목적을 알려주세요.\n 1.운동 종류 둘러보기 2.사용자 맞춤 운동 추천받기 : '))
#         p_li = ['운동 종류 둘러보기', '사용자 맞춤 운동 추천받기']
#         if pq <3 :
#             return'{}번 {}를 선택하셨습니다. {}님이 원하시는 프로그램을 제공해드리겠습니다. 잠시만 기다려주세요.'.format(pq, p_li[pq-1],name)
#             break
#         else :
#             continue     
    while 1 :
        try:
            sleep(0.5)
            pq = int(input('\n프로그램의 사용 목적을 알려주세요.\n 1.운동 종류 둘러보기 2.사용자 맞춤 운동 추천받기 : '))
            p_li = ['운동 종류 둘러보기', '사용자 맞춤 운동 추천받기']
        except :
            sleep(0.5)
            print("잘못 입력하셨습니다.\n보기에 있는 숫자를 입력해주세요.")
            continue
        if 1< pq <3 :
            print('\n{}번 {}를 선택하셨습니다.'.format(pq, p_li[pq-1]))
            sleep(1)
            print('{}님이 원하시는 프로그램을 제공해드리기 위해 노력중입니다. 잠시만 기다려주세요.'.format(name))
            sleep(1)      
            break
        elif pq == 1:
            while 1:
                try:
                    sleep(1)
                    print(workoutlist = ['자기 전 요가', '5분 복근만들기', '유산소 운동', '1분 플랭크', '하체운동', '이두/삼두/어깨운동','생활속운동','거북목방지운동'])
                    break
                except :
                    sleep(1)
                    print('운동 종류 : 자기 전 요가, 5분 복근만들기, 유산소 운동, 1분 플랭크, 하체운동, 이두/삼두/어깨운동,생활속운동,거북목방지운동')
                    break
            sleep(1)
            try :    
                qq = input('앞의 선택지로 다시 돌아가시겠습니까?(예/아니오): ')
                if qq == '예':
                    continue
                elif qq == '아니오' :
                    sleep(1)
                    print('프로그램을 종료하고 처음으로 돌아갑니다. 잠시만 기다려주세요.')
                    sleep(1.5)
                    name = input('반갑습니다 사용자님, 성함을 입력해주세요 : ')
                    sleep(0.5)
                    print("{}님께서 집에서도 할 수 있는, 오늘의 운동을 추천해드립니다.".format(name))
                    sleep(0.5)
                    print(program_function())
                    sleep(1)
                    break
                else :
                    continue
            except :
                continue

        else :
            sleep(0.5)
            print('목록에 있는 번호로 다시 입력해주세요')
            continue        
        



name = input('반갑습니다 사용자님, 성함을 입력해주세요 : ')
print("{}님께서 집에서도 할 수 있는, 오늘의 운동을 추천해드립니다.".format(name))
sleep(1)
print("프로그램을 로딩중에 있습니다. 잠시만 기다려주세요.")
sleep(1.5)
workoutlist = ['자기 전 요가', '5분 복근만들기', '유산소 운동', '1분 플랭크', '하체운동', '이두/삼두/어깨운동','생활속운동','거북목방지운동']

while 1 :
    try:
        sleep(0.5)
        pq = int(input('\n프로그램의 사용 목적을 알려주세요.\n 1.운동 종류 둘러보기 2.사용자 맞춤 운동 추천받기 : '))
        p_li = ['운동 종류 둘러보기', '사용자 맞춤 운동 추천받기']
    except :
        sleep(0.5)
        print("잘못 입력하셨습니다.\n보기에 있는 숫자를 입력해주세요.")
        continue
    if 1< pq <3 :
        print('\n{}번 {}를 선택하셨습니다.'.format(pq, p_li[pq-1]))
        sleep(1)
        print('{}님이 원하시는 프로그램을 제공해드리기 위해 노력중입니다. 잠시만 기다려주세요.'.format(name))
        sleep(1)      
        break
    elif pq == 1:
        while 1:
            try:
                sleep(1)
                print(workoutlist = ['자기 전 요가', '5분 복근만들기', '유산소 운동', '1분 플랭크', '하체운동', '이두/삼두/어깨운동','생활속운동','거북목방지운동'])
                break
            except :
                sleep(1)
                print('운동 종류 : 자기 전 요가, 5분 복근만들기, 유산소 운동, 1분 플랭크, 하체운동, 이두/삼두/어깨운동,생활속운동,거북목방지운동')
                break
        sleep(1)
        try :    
            qq = input('앞의 선택지로 다시 돌아가시겠습니까?(예/아니오): ')
            if qq == '예':
                continue
            elif qq == '아니오' :
                sleep(1)
                print('프로그램을 종료하고 처음으로 돌아갑니다. 잠시만 기다려주세요.')
                sleep(1.5)
                name = input('반갑습니다 사용자님, 성함을 입력해주세요 : ')
                sleep(0.5)
                print("{}님께서 집에서도 할 수 있는, 오늘의 운동을 추천해드립니다.".format(name))
                sleep(0.5)
                print(program_function())
                sleep(1)
                break
            else :
                print("잘못입력하셨습니다. 앞의 선택지로 다시돌아갑니다.")
                continue
        except :
            print("잘못입력하셨습니다. 앞의 선택지로 다시돌아갑니다.")
     
    else :
        sleep(0.5)
        print('목록에 있는 번호로 다시 입력해주세요')
        continue        

while 1 :
    cq = int(input('\n오늘의 몸 상태는 어떠세요?\n 1. 활력 넘침 2. 보통 3. 피곤함: '))
    c_li = ['활력넘침', '보통', '피곤함']
    if cq < 4:
        sleep(1)
        print('\n{}번 {}을 선택하셨습니다. {}님의 컨디션에 맞는 운동을 추천하기 위해 정보를 수집중입니다.'.format(cq, c_li[cq-1], name))
        break
    else : 
        sleep(0.5)
        print('목록에 있는 번호로 다시 입력해주세요.')
        continue

while 1:
    sleep(1)
    wq = int(input('\n운동 목적을 입력해주세요.\n 1.스트레칭 2.근력증진 3.체중감량 : '))
    w_li = ['스트레칭', '근력증진', '체중감량']
    if wq < 4:
        sleep(1)
        print('\n{}번 {}를 선택하셨습니다. {}님이 원하시는 프로그램을 제공해드리겠습니다. 잠시만 기다려주세요.'.format(wq, w_li[wq-1], name))
        break
    else :
        sleep(0.5)
        print('목록에 있는 번호로 다시 입력해주세요.')
        continue 

                
while 1:
    sleep(1)
    tq = int(input('\n운동 가능한 시간을 알려주세요.\n 1. 10분이하 2. 30분이하 3. 1시간 이하 : '))
    t_li = ['10분이하', '30분이하', '1시간이하']
    if tq < 4 :
        sleep(1)
        print('\n{}번 {}를(을) 선택하셨습니다. {}님의 편의에 맞는 운동을 추천드리기 위해 더 똑똑해지고 있습니다.'.format(tq, t_li[tq-1],name))
        break      
    else :
        sleep(0.5)
        print('목록에 있는 번호로 다시 입력해주세요.')
        continue 

sleep(1)
print('{}님의 맞춤형 운동을 추천하기 위한 결과가 거의 다 나왔습니다. 아주 잠시만 기다려주세요.'.format(name))
sleep(0.5)
print(5)
sleep(0.5)
print(4)
sleep(0.5)
print(3)
sleep(0.5)
print(2)
sleep(0.5)
print(1)
if pq == 2 and wq ==1 : #스트레칭
    sleep(1)
    print("{}님 맞춤형 운동 결과가 나왔습니다.".format(name))
    sleep(1)
    print("{}님이 선택하신 결과에 따라 스트레칭을 추천해드리겠습니다.".format(name))
    print("{}님께 추천드리는 스트레칭 리스트는 다음과 같습니다.".format(name))
    pq1 = int(input("1. 자기 전 요가 2. 생활 속 운동 3. 거북목 방지 운동중 원하는 코스를 선택해주세요:  "))
    if pq1 == 1 :#자기전요가
        f = open("C:\workplace\cakd3\programming\workout\자기전요가.txt", 'r', encoding='UTF8')
        while True:
            line = f.readline()
            sleep(0.7)
            if not line: break
            print(line)
        f.close()
    elif pq1 == 2: #생활속운동
        f = open("C:\workplace\cakd3\programming\workout\생활속운동.txt", 'r', encoding='UTF8')
        while True:
            line = f.readline()
            sleep(0.7)
            if not line: break
            print(line)
        f.close()
    elif pq1 == 3: #거북목방지운동
        f = open("C:\workplace\cakd3\programming\workout\거북목방지운동.txt", 'r', encoding='UTF8')
        while True:
            line = f.readline()
            sleep(0.7)
            if not line: break
            print(line)
        f.close()
if pq == 2 and wq ==2 : #근력증진
    sleep(1)
    print("{}님 맞춤형 운동 결과가 나왔습니다.".format(name))
    sleep(1)
    print("{}님이 선택하신 결과에 따라 근력증진 운동을 추천해드리겠습니다.".format(name, name))
    print("{}님께 추천드리는 스트레칭 리스트는 다음과 같습니다.".format(name))
    pq1 = int(input("1. 1분 플랭크 2. 이두/삼두/어깨 운동 3. 5분 복근만들기 중 원하는 번호를 입력해주세요:  "))
    if pq1 == 1 :#플랭크
        f = open("C:\workplace\cakd3\programming\workout\플랭크.txt", 'r', encoding='UTF8')
        while True:
            line = f.readline()
            sleep(0.7)
            if not line: break
            print(line)
        f.close()
    elif pq1 == 2: #이두삼두어깨운동
        f = open("C:\workplace\cakd3\programming\workout\어깨및팔근육운동.txt", 'r', encoding='UTF8')
        while True:
            line = f.readline()
            sleep(0.7)
            if not line: break
            print(line)
        f.close()
    elif pq1 == 3: #복근만들기운동
        f = open("C:\workplace\cakd3\programming\workout\복근만들기운동.txt", 'r', encoding='UTF8')
        while True:
            line = f.readline()
            sleep(0.7)
            if not line: break
            print(line)
        f.close()
if pq == 2 and wq ==3 : #체중감량
    sleep(1)
    print("{}님 맞춤형 운동 결과가 나왔습니다.".format(name))
    sleep(1)
    print("{}님이 선택하신 결과에 따라 근력증진 운동을 추천해드리겠습니다.".format(name, name))
    print("{}님께 추천드리는 스트레칭 리스트는 다음과 같습니다.".format(name))
    pq1 = int(input("1. 하체운동 2.유산소운동 3.5분 복근만들기 중 원하는 번호를 입력해주세요:  "))
    if pq1 == 1 :#하체운동
        f = open("C:\workplace\cakd3\programming\workout\하체운동루틴.txt", 'r', encoding='UTF8')
        while True:
            line = f.readline()
            sleep(0.7)
            if not line: break
            print(line)
        f.close()
    elif pq1 == 2: #유산소운동
        f = open("C:\workplace\cakd3\programming\workout\유산소운동.txt", 'r', encoding='UTF8')
        while True:
            line = f.readline()
            sleep(0.7)
            if not line: break
            print(line)
        f.close()
    elif pq1 == 3: #복근운동
        f = open("C:\workplace\cakd3\programming\workout\복근만들기운동.txt", 'r', encoding='UTF8')
        while True:
            line = f.readline()
            sleep(0.7)
            if not line: break
            print(line)
        f.close()
sleep(1)        
print("\n운동이 끝났습니다. 오늘 운동은 만족스러우셨나요? 다음에 꼭 다시 뵐 수 있다면 좋겠습니다.")
# Out:
# 반갑습니다 사용자님, 성함을 입력해주세요 : d
# d님께서 집에서도 할 수 있는, 오늘의 운동을 추천해드립니다.
# 프로그램을 로딩중에 있습니다. 잠시만 기다려주세요.
#
# 프로그램의 사용 목적을 알려주세요.
#  1.운동 종류 둘러보기 2.사용자 맞춤 운동 추천받기 : 2
#
# 2번 사용자 맞춤 운동 추천받기를 선택하셨습니다.
# d님이 원하시는 프로그램을 제공해드리기 위해 노력중입니다. 잠시만 기다려주세요.
#
# 오늘의 몸 상태는 어떠세요?
#  1. 활력 넘침 2. 보통 3. 피곤함: 1
#
# 1번 활력넘침을 선택하셨습니다. d님의 컨디션에 맞는 운동을 추천하기 위해 정보를 수집중입니다.
#
# 운동 목적을 입력해주세요.
#  1.스트레칭 2.근력증진 3.체중감량 : 2
#
# 2번 근력증진를 선택하셨습니다. d님이 원하시는 프로그램을 제공해드리겠습니다. 잠시만 기다려주세요.
#
# 운동 가능한 시간을 알려주세요.
#  1. 10분이하 2. 30분이하 3. 1시간 이하 : 3
#
# 3번 1시간이하를(을) 선택하셨습니다. d님의 편의에 맞는 운동을 추천드리기 위해 더 똑똑해지고 있습니다.
# d님의 맞춤형 운동을 추천하기 위한 결과가 거의 다 나왔습니다. 아주 잠시만 기다려주세요.
# 5
# 4
# 3
# 2
# 1
# d님 맞춤형 운동 결과가 나왔습니다.
# d님이 선택하신 결과에 따라 근력증진 운동을 추천해드리겠습니다.
# d님께 추천드리는 스트레칭 리스트는 다음과 같습니다.
# 1. 1분 플랭크 2. 이두/삼두/어깨 운동 3. 5분 복근만들기 중 원하는 번호를 입력해주세요:  2
# <어깨 및 팔 근육 운동>
#
# 1. 덤벨 숄더프레스 (삼두운동)
#
# step1) 바르게 서서 척추를 중립으로 유지하고 어깨를 펴고 몸이 흔들리지 않도록 주의합니다.
#
# step2) 덤벨을 든 손을 귀옆에서 시작해 천장으로 천천히 폅니다.
#
# step3) 내릴 때도 너무 빠르게 내리지 않게 주의해주세요.
#
# ...
